# %% [markdown]
# ### Sushant Dobhal
#
# ### 2301560038
#
# ### MCA
#
# ### AI & Machine learning

# %% [markdown]
# # Branch Performance Analysis in Retail

# %% [markdown]
# ## 1. Problem Description:
#
# (i) Understand the contribution of each product line to overall sales and identify areas for improvement or expansion.
#
# (ii) Investigate how gender influences product preferences and purchasing behavior to customize offerings.
#
# (iii) Evaluate the gross margin percentage and gross income to assess overall financial performance and profitability.
#
# (iv) Understand the distribution of payment methods used by customers to optimize payment processing systems.

# %% [markdown]
# ## 2.Objectives:
#
# (i) Determine which branches contribute the most to overall sales and profitability.
#
# (ii) Understand the distribution of payment methods used by customers and optimize payment processing systems accordingly.
#
# (iii) Break down costs, including COGS and taxes, to identify areas for cost reduction and operational efficiency.

# %% [markdown]
# ## 3.Applications:
#
# (i) Assess the impact of promotions on sales and profitability to refine future marketing strategies.
#
# (ii) Use data patterns to detect irregularities or anomalies in transactions that may indicate potential fraud.

# %% [markdown]
# ## Introduction:
#
# Embarking on a journey into the realm of retail analysis, this project centers on deciphering the intricacies of sales, customer dynamics, and financial performance. The dataset under examination provides a comprehensive snapshot of transactions, spanning across various branches, cities, and customer segments. Our exploration delves into the essential elements that shape retail operations, seeking to extract meaningful insights that can inform strategic decision-making.
#
# By navigating through the complexities of pricing, inventory management, and financial metrics, we aim to uncover patterns and trends that hold the key to optimizing retail performance. The focus is not merely on transactional details but on the broader landscape, where each piece of information contributes to a holistic understanding of the retail ecosystem.
#
# In this endeavor, our goal is to equip stakeholders with actionable intelligence, enabling them to make informed choices that align with market demands and enhance overall operational efficiency. Through this analysis, we aspire to reveal the underlying story within the data, providing a foundation for strategic and data-driven decision-making in the dynamic world of retail.

# %% [markdown]
# ## Project Overview:
#
# This project explores a retail dataset encompassing attributes such as Branch, City, Customer type, Gender, Product line, and financial metrics. Focusing on sales dynamics, customer behavior, and profitability, our goal is to extract actionable insights for informed decision-making, optimizing operational efficiency, and enhancing overall retail performance.

# %% [markdown]
# ### 1) Features Available:
# (i) Branch (ii) City (iii) Customer type (iv) Gender (v) Product line (vi) Unit price (vii) Quantity

# %% [markdown]
# ### 2) Objective:
#
# The project aims to extract actionable insights from a retail dataset, analyzing features such as branch, city, customer type, and financial metrics. Objectives include optimizing sales strategies, understanding customer behavior, and enhancing profitability, enabling informed decision-making for improved operational efficiency and overall retail performance.

# %% [markdown]
# ### 3) Potential Applications:
#
# (i) Optimize inventory levels based on historical sales data and product line information.
#
# (ii) Investigate temporal trends to understand seasonality and optimize marketing efforts.

# %% [markdown]
# ## Description:
#
# The dataset encompasses key attributes characterizing retail transactions, including Branch, City, Customer type, Gender, and Product line. Financial details such as Unit price, Quantity, Tax 5%, Total, Payment, COGS (Cost of Goods Sold), Gross Margin Percentage, and Gross Income provide insights into pricing, sales dynamics, and profitability. This comprehensive dataset facilitates analysis of customer behavior, branch performance, and operational efficiency, making it invaluable for deriving actionable insights to optimize various facets of retail management.

# %% [markdown]
# ## Summary:
#
# The dataset under consideration captures crucial information from retail transactions, enabling a comprehensive analysis of sales, customer behavior, and financial performance. It facilitates insights into pricing strategies, payment methods, and branch-specific dynamics, offering opportunities for targeted marketing, inventory optimization, and cost-efficient operations. This dataset serves as a valuable resource for data-driven decision-making in the dynamic realm of retail management.

# %% [markdown]
# ## Dataset Information:
#
# (i) Branch: Specific branch where the transaction occurred.
#
# (ii) City: City in which the branch is located.
#
# (iii) Customer type: Type of customer involved in the transaction (e.g., Member, Normal).
#
# (iv) Gender: Gender of the customer.
#
# (v) Product line: Category or type of product involved in the transaction.
#
# (vi) Unit price: Price per unit of the product.
#
# (vii) Quantity: Quantity of the product purchased.
#
# (viii) Tax 5%: Tax amount calculated as 5% of the total.
#
# (ix) Total: Total amount including the product cost, tax, and other charges.
#
# (x) Payment: Payment method used for the transaction.
#
# (xi) COGS (Cost of Goods Sold): Cost of producing or purchasing the products sold.
#
# (xii) Gross margin percentage: Percentage representing the gross profit margin.
#
# (xiii) Gross income: Total gross profit generated from the transaction.

# %% [markdown]
# ## Attribute Information:
#
# These attributes collectively provide comprehensive information about retail transactions, enabling analyses related to sales, customer behavior, pricing, profitability, and operational efficiency.

# %% [markdown]
# ## Project Outline:

# %% [markdown]
# ##

# %% [markdown]
# # 1. Import Packages

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import scipy as sp
import warnings
import datetime
warnings.filterwarnings("ignore")
# %matplotlib inline

# %% [markdown]
# # 2. Read Data

# %%
df = pd.read_csv("/Users/sushantdobhal/Downloads/supermarket_sales - Sheet1.csv")

# %%
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %% [markdown]
# ## Data Information:

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
# ...

# %% [markdown]
# ## Data Processing:

# %%
np.round(data.isnull().sum()*100.00/len(data),2)
# Out:
# Invoice ID                 0.0
# Branch                     0.0
# City                       0.0
# Customer type              0.0
# Gender                     0.0
# Product line               0.0
# Unit price                 0.0
# Quantity                   0.0
# Tax 5%                     0.0
# Total                      0.0
# Date                       0.0
# Time                       0.0
# Payment                    0.0
# cogs                       0.0
# gross margin percentage    0.0
# gross income               0.0
# Rating                     0.0
# dtype: float64

# %%
df.describe()
# Out:
#         Unit price     Quantity       Tax 5%        Total        cogs  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000
# mean     55.672130     5.510000    15.379369   322.966749   307.58738
# std      26.494628     2.923431    11.708825   245.885335   234.17651
# min      10.080000     1.000000     0.508500    10.678500    10.17000
# 25%      32.875000     3.000000     5.924875   124.422375   118.49750
# 50%      55.230000     5.000000    12.088000   253.848000   241.76000
# 75%      77.935000     8.000000    22.445250   471.350250   448.90500
# max      99.960000    10.000000    49.650000  1042.650000   993.00000
#
#        gross margin percentage  gross income      Rating
# count             1.000000e+03   1000.000000  1000.00000
# mean              4.761905e+00     15.379369     6.97270
# std               6.131498e-14     11.708825     1.71858
# min               4.761905e+00      0.508500     4.00000
# ...

# %%
print(f'Duplicate rows: {data.duplicated().sum()}')
# Out:
# Duplicate rows: 0

# %%
temp_data = data.copy()
cols = temp_data.columns.tolist()
print(f'Duplicate columns: {temp_data.T.duplicated().sum()}')
# Out:
# Duplicate columns: 1

# %%
df.shape
# Out:
# (1000, 17)

# %%
df.size
# Out:
# 17000

# %%
df.dtypes
# Out:
# Invoice ID                  object
# Branch                      object
# City                        object
# Customer type               object
# Gender                      object
# Product line                object
# Unit price                 float64
# Quantity                     int64
# Tax 5%                     float64
# Total                      float64
# Date                        object
# Time                        object
# Payment                     object
# cogs                       float64
# gross margin percentage    float64
# gross income               float64
# Rating                     float64
# dtype: object

# %%
df.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %% [markdown]
# **Checking Null Value**

# %%
df.isnull().sum()
# Out:
# Invoice ID                 0
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Date                       0
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %%
df.isnull().any()
# Out:
# Invoice ID                 False
# Branch                     False
# City                       False
# Customer type              False
# Gender                     False
# Product line               False
# Unit price                 False
# Quantity                   False
# Tax 5%                     False
# Total                      False
# Date                       False
# Time                       False
# Payment                    False
# cogs                       False
# gross margin percentage    False
# gross income               False
# Rating                     False
# dtype: bool

# %% [markdown]
# ## 3) Exploratory Data Analysis:

# %%
df.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
df.nunique()
# Out:
# Invoice ID                 1000
# Branch                        3
# City                          3
# Customer type                 2
# Gender                        2
# Product line                  6
# Unit price                  943
# Quantity                     10
# Tax 5%                      990
# Total                       990
# Date                         89
# Time                        506
# Payment                       3
# cogs                        990
# gross margin percentage       1
# gross income                990
# Rating                       61
# dtype: int64

# %% [markdown]
# ## 4) Histogram

# %%
df.hist(figsize=(20,14))
plt.show()

# %%
print(df.dtypes)

# Identify columns with non-numeric values
non_numeric_columns = df.select_dtypes(exclude=['float64', 'int64']).columns
print("Columns with non-numeric values:", non_numeric_columns)
# Out:
# Invoice ID                  object
# Branch                      object
# City                        object
# Customer type               object
# Gender                      object
# Product line                object
# Unit price                 float64
# Quantity                     int64
# Tax 5%                     float64
# Total                      float64
# Date                        object
# Time                        object
# Payment                     object
# cogs                       float64
# gross margin percentage    float64
# gross income               float64
# Rating                     float64
# dtype: object
# Columns with non-numeric values: Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Date', 'Time', 'Payment'],
#       dtype='object')

# %%
numeric_data = data.select_dtypes(include=['float64', 'int64'])
correlation_matrix = numeric_data.corr()
# Display the correlation matrix
print(correlation_matrix)
# Out:
#                          Unit price  Quantity    Tax 5%     Total      cogs  \
# Unit price                 1.000000  0.010778  0.633962  0.633962  0.633962
# Quantity                   0.010778  1.000000  0.705510  0.705510  0.705510
# Tax 5%                     0.633962  0.705510  1.000000  1.000000  1.000000
# Total                      0.633962  0.705510  1.000000  1.000000  1.000000
# cogs                       0.633962  0.705510  1.000000  1.000000  1.000000
# gross margin percentage         NaN       NaN       NaN       NaN       NaN
# gross income               0.633962  0.705510  1.000000  1.000000  1.000000
# Rating                    -0.008778 -0.015815 -0.036442 -0.036442 -0.036442
#
#                          gross margin percentage  gross income    Rating
# Unit price                                   NaN      0.633962 -0.008778
# Quantity                                     NaN      0.705510 -0.015815
# ...

# %% [markdown]
# ## 5) HEATMAP

# %%
plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='tab20b', fmt='.2f')
plt.show()

# %%
df.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %% [markdown]
# ## 6) BOXPLOT

# %%
plt.figure(figsize=(14,10))
sns.set_style(style='whitegrid')
plt.subplot(2,3,1)
sns.boxplot(x='Unit price',data=data)
plt.subplot(2,3,2)
sns.boxplot(x='Quantity',data=data)
plt.subplot(2,3,3)
sns.boxplot(x='Total',data=data)
plt.subplot(2,3,4)
sns.boxplot(x='cogs',data=data)
plt.subplot(2,3,5)
sns.boxplot(x='Rating',data=data)
plt.subplot(2,3,6)
sns.boxplot(x='gross income',data=data)
# Out:
# <Axes: xlabel='gross income'>

# %% [markdown]
# ## 7) REGPLOT

# %%
sns.regplot(x='Rating', y= 'gross income', data=data)
# Out:
# <Axes: xlabel='Rating', ylabel='gross income'>

# %% [markdown]
# ## 8) PAIRPLOT

# %%
sns.pairplot(data=data)

# %% [markdown]
# ## 9) SCATTER PLOT

# %%
sns.scatterplot(x='Rating', y= 'cogs', data=data)
# Out:
# <Axes: xlabel='Rating', ylabel='cogs'>

# %% [markdown]
# ## 10) CATPLOT

# %%
sns.catplot(x='Rating', y= 'cogs', data=data)

# %% [markdown]
# ## 11) LMPLOT

# %%
sns.lmplot(x='Rating', y= 'cogs', data=data)

# %% [markdown]
# ## 12) JOINTPLOT

# %%
sns.jointplot(x='Rating', y= 'Total', data=data)

# %% [markdown]
# ## 13) LINEPLOT

# %%
sns.lineplot(x='Rating', y= 'Unit price', data=data)
# Out:
# <Axes: xlabel='Rating', ylabel='Unit price'>

# %% [markdown]
# ## 14) KDE PLOT (DENSITY PLOT)

# %%
plt.style.use("default")

sns.kdeplot(x='Rating', y= 'Unit price', data=data)
# Out:
# <Axes: xlabel='Rating', ylabel='Unit price'>

# %% [markdown]
# ## 15) BARPLOT

# %%
plt.style.use("default")
plt.figure(figsize=(5,5))
sns.barplot(x="Rating", y="Unit price", data=data[170:180])
plt.title("Rating vs Unit Price",fontsize=15)
plt.xlabel("Rating")
plt.ylabel("Unit Price")
plt.show()

# %%
df.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %% [markdown]
# ### 16) Customer Type

# %%
plt.figure(figsize= (14,6))
ax = sns.countplot(x = "Customer type", data = data, palette = "rocket_r")
ax.set_title("Type of customers", fontsize = 25)
ax.set_xlabel("Customer type", fontsize = 16)
ax.set_ylabel("Customer Count", fontsize = 16)
# Out:
# Text(0, 0.5, 'Customer Count')

# %%
df.groupby(['Customer type']). agg({'Total':'sum'})
# Out:
#                     Total
# Customer type
# Member         164223.444
# Normal         158743.305

# %% [markdown]
# ### 17) Customer in different branch.

# %%
plt.figure(figsize=(14,6))
ax = sns.countplot(x = "Customer type", hue = "Branch", data = data, palette= "rocket_r")
ax.set_title(label = "Customer type in different branch", fontsize = 25)
ax.set_xlabel(xlabel = "Branches", fontsize = 16)
ax.set_ylabel(ylabel = "Customer Count", fontsize = 16)
# Out:
# Text(0, 0.5, 'Customer Count')

# %% [markdown]
# ### 18) Payment methods used which are different.

# %%
plt.figure(figsize = (14,6))
ax = sns.countplot(x = "Payment", data = data, palette = "tab20")
ax.set_title(label = "Payment methods of customers ", fontsize= 25)
ax.set_xlabel(xlabel = "Payment method", fontsize = 16)
ax.set_ylabel(ylabel = " Customer Count", fontsize = 16)
# Out:
# Text(0, 0.5, ' Customer Count')

# %% [markdown]
# ### 19) Sales count of the products.

# %%
plt.figure(figsize=(14,6))
ax = sns.countplot(y='Product line', data=data, order = data['Product line'].value_counts().index)
ax.set_title(label = "Sales count of the products", fontsize = 30)
ax.set_xlabel(xlabel = "Sales count", fontsize = 20)
ax.set_ylabel(ylabel= "Product Line", fontsize = 20)
# Out:
# Text(0, 0.5, 'Product Line')

# %% [markdown]
# ### 20) Total costs by Branch

# %%
cogs_column = 'cogs'
taxes_column = 'Tax 5%'

# Calculate total costs
df['Total Costs'] = df[cogs_column] + df[taxes_column]
branch_costs = df.groupby('Branch')['Total Costs'].sum()

product_line_costs = df.groupby('Product line')['Total Costs'].sum()
# Identify areas with high costs
high_cost_branches = branch_costs[branch_costs > branch_costs.mean()]

# Identify areas with high costs by product line
high_cost_product_lines = product_line_costs[product_line_costs > product_line_costs.mean()]

branch_costs.plot(kind='bar', title='Total Costs by Branch')
plt.show()

# %% [markdown]
# ### 21) Product Preferences by Gender

# %%
# Visualize product preferences by gender
plt.figure(figsize=(12, 6))
sns.countplot(x='Product line', hue='Gender', data=df)
plt.title('Product Preferences by Gender')
plt.xlabel('Product Line')
plt.ylabel('Count')
plt.show()

# Analyze purchasing behavior
gender_purchase_stats = df.groupby('Gender').agg({
    'Total': ['sum', 'mean', 'count'],
    'Quantity': ['sum', 'mean'],
    'Tax 5%': 'sum',
    'cogs': 'sum'
}).reset_index()

print(gender_purchase_stats)

plt.figure(figsize=(12, 6))
sns.barplot(x='Gender', y='Total', data=df, estimator=sum)
plt.title('Total Purchase Amount by Gender')
plt.xlabel('Gender')
plt.ylabel('Total Purchase Amount')
plt.show()
# Out:
#    Gender       Total                   Quantity              Tax 5%  \
#                   sum        mean count      sum      mean       sum
# 0  Female  167882.925  335.095659   501     2869  5.726547  7994.425
# 1    Male  155083.824  310.789226   499     2641  5.292585  7384.944
#
#         cogs
#          sum
# 0  159888.50
# 1  147698.88

# %% [markdown]
# ### 22) Distribution of Gross Margin Percentage

# %%
# Calculate gross margin percentage and gross income
df['Gross Margin Percentage'] = (df['gross margin percentage'] / 100) * df['Total']

gross_stats = df[['Gross Margin Percentage', ]].describe()

print(gross_stats)

plt.figure(figsize=(12, 6))
sns.histplot(df['Gross Margin Percentage'], bins=20, kde=True, color='skyblue', label='Gross Margin Percentage')
plt.title('Distribution of Gross Margin Percentage')
plt.xlabel('Gross Margin Percentage')
plt.ylabel('Frequency')
plt.legend()
plt.show()
# Out:
#        Gross Margin Percentage
# count              1000.000000
# mean                 15.379369
# std                  11.708825
# min                   0.508500
# 25%                   5.924875
# 50%                  12.088000
# 75%                  22.445250
# max                  49.650000

# %% [markdown]
# ### 23)  Distribution of Gross Income

# %%
df['Gross Income'] = df['Total'] - df['cogs']
gross_stats = df[['Gross Income']].describe()
print(gross_stats)
plt.figure(figsize=(12, 6))
sns.histplot(df['Gross Income'], bins=20, kde=True, color='salmon', label='Gross Income')
plt.title('Distribution of Gross Income')
plt.xlabel('Gross Income')
plt.ylabel('Frequency')
plt.legend()
plt.show()
# Out:
#        Gross Income
# count   1000.000000
# mean      15.379369
# std       11.708825
# min        0.508500
# 25%        5.924875
# 50%       12.088000
# 75%       22.445250
# max       49.650000

# %% [markdown]
# ### 24) most popular cities in terms of sales and customer ratings

# %%
city_data = df.groupby('City')[['Total', 'Rating']].agg(['sum', 'mean'])
city_data = city_data.sort_values(('Total', 'sum'), ascending=False)
print('Most popular cities:')
print(city_data.head(10))

# visualize the most popular cities in terms of sales and customer ratings
city_data.head(10).plot(kind='bar', title='Most Popular Cities in Sales and Customer Ratings')
# Out:
# Most popular cities:
#                  Total              Rating
#                    sum        mean     sum      mean
# City
# Naypyitaw  110568.7065  337.099715  2319.9  7.072866
# Yangon     106200.3705  312.354031  2389.2  7.027059
# Mandalay   106197.6720  319.872506  2263.6  6.818072
# <Axes: title={'center': 'Most Popular Cities in Sales and Customer Ratings'}, xlabel='City'>

# %% [markdown]
# ### 25) Top Groups With The Highest Average Customer Ratings

# %%
customer_data = df.groupby(['Gender', 'Customer type', 'Payment', 'Product line'])['Rating'].mean()

customer_data = customer_data.sort_values(ascending=False)

# print the top 10 groups with the highest average customer ratings
print('Top 10 groups with the highest average customer ratings:')
print(customer_data.head(10))

customer_data.head(10).plot(kind='bar', title = 'Top Groups With The Highest Average Customer Ratings')
# Out:
# Top 10 groups with the highest average customer ratings:
# Gender  Customer type  Payment      Product line
# Female  Member         Credit card  Electronic accessories    8.050000
# Male    Normal         Credit card  Electronic accessories    7.925000
# Female  Normal         Cash         Food and beverages        7.876923
# Male    Member         Credit card  Electronic accessories    7.843750
#                        Ewallet      Health and beauty         7.815385
# Female  Normal         Cash         Health and beauty         7.738462
# Male    Normal         Ewallet      Sports and travel         7.584211
# Female  Member         Ewallet      Home and lifestyle        7.520000
#                        Cash         Food and beverages        7.485000
#         Normal         Cash         Fashion accessories       7.476471
# Name: Rating, dtype: float64
# ...

# %% [markdown]
# ### 26) Top Groups With The Lowest Average Customer Ratings

# %%
customer_dataa = df.groupby(['Gender', 'Customer type', 'Payment', 'Product line'])['Rating'].mean()

customer_dataa = customer_data.sort_values()

# print the top 10 groups with the lowest average customer ratings
print('Top 10 groups with the lowest average customer ratings:')
print(customer_dataa.head(10))

customer_dataa.head(10).plot(kind='bar', title = 'Top Groups With The Lowest Average Customer Ratings')
# Out:
# Top 10 groups with the lowest average customer ratings:
# Gender  Customer type  Payment      Product line
# Male    Member         Cash         Home and lifestyle        6.073333
# Female  Member         Ewallet      Food and beverages        6.100000
#         Normal         Credit card  Home and lifestyle        6.133333
#         Member         Ewallet      Sports and travel         6.181250
#         Normal         Ewallet      Sports and travel         6.227273
#         Member         Ewallet      Electronic accessories    6.250000
#         Normal         Credit card  Electronic accessories    6.250000
# Male    Member         Credit card  Home and lifestyle        6.300000
# Female  Normal         Ewallet      Home and lifestyle        6.335714
#                                     Health and beauty         6.392857
# Name: Rating, dtype: float64
# ...

# %% [markdown]
# ### 27) Total sales per month, transactions per week, transactions per day.

# %%
# total sales per month
df['Date'] = pd.to_datetime(df['Date'])
monthly_sales = df.groupby(df['Date'].dt.strftime('%B'))['Total'].sum()

print(monthly_sales)

monthly_sales.plot(kind='bar', title = 'Monthly Sales')
# Out:
# Date
# February     97219.374
# January     116291.868
# March       109455.507
# Name: Total, dtype: float64
# <Axes: title={'center': 'Monthly Sales'}, xlabel='Date'>

# %%
# total number of transactions per week
df['Date'] = pd.to_datetime(df['Date'])
transactions_per_week = df.groupby(df['Date'].dt.strftime('%U'))['Invoice ID'].nunique()

print(transactions_per_week)

transactions_per_week.plot(kind='bar', title = 'Transactions Per Week')
# Out:
# Date
# 00    46
# 01    72
# 02    82
# 03    89
# 04    83
# 05    95
# 06    70
# 07    64
# 08    82
# 09    90
# 10    84
# 11    71
# 12    72
# Name: Invoice ID, dtype: int64
# <Axes: title={'center': 'Transactions Per Week'}, xlabel='Date'>

# %%
# total number of transactions per day
df['Date'] = pd.to_datetime(df['Date'])
transactions_per_day = df.groupby(df['Date'].dt.strftime('%a'))['Invoice ID'].nunique()

print(transactions_per_day)

transactions_per_day.plot(kind='bar', title='Transaction Per Day')
# Out:
# Date
# Fri    139
# Mon    125
# Sat    164
# Sun    133
# Thu    138
# Tue    158
# Wed    143
# Name: Invoice ID, dtype: int64
# <Axes: title={'center': 'Transaction Per Day'}, xlabel='Date'>

# %% [markdown]
# ### 28) Top purchased products on weekends vs weekdays

# %%
product_data = df.groupby(['Product line', df['Date'].dt.strftime('%a')])['Quantity'].sum()

# select the groups for weekends and weekdays
weekend_data = product_data.loc[:, ['Sat', 'Sun']]
weekday_data = product_data.loc[:, ['Mon', 'Tue', 'Wed', 'Thu', 'Fri']]

weekend_data = weekend_data.groupby('Product line').sum()
weekday_data = weekday_data.groupby('Product line').sum()

weekend_data = weekend_data.sort_values(ascending=False)
weekday_data = weekday_data.sort_values(ascending=False)

# %%
# Top products sold on weekdays
print('Top products sold on weekdays:')
print(weekday_data.head(10))

weekday_data.head(10).plot(kind='bar', title = 'Top Products Sold on Weekdays')
# Out:
# Top products sold on weekdays:
# Product line
# Electronic accessories    678
# Health and beauty         667
# Food and beverages        662
# Fashion accessories       620
# Sports and travel         611
# Home and lifestyle        575
# Name: Quantity, dtype: int64
# <Axes: title={'center': 'Top Products Sold on Weekdays'}, xlabel='Product line'>

# %%
# Top products sold on weekends
print('Top products sold on weekends:')
print(weekend_data.head(10))

weekend_data.head(10).plot(kind='bar', title = 'Top Products Sold on Weekends')
# Out:
# Top products sold on weekends:
# Product line
# Home and lifestyle        336
# Sports and travel         309
# Electronic accessories    293
# Food and beverages        290
# Fashion accessories       282
# Health and beauty         187
# Name: Quantity, dtype: int64
# <Axes: title={'center': 'Top Products Sold on Weekends'}, xlabel='Product line'>

# %% [markdown]
# ### 29) Rating VS Gender

# %%
plt.style.use("default")
plt.figure(figsize=(5,5))
sns.barplot(x="Rating", y="Gender", data=data[170:180])
plt.title("Rating vs Gender",fontsize=15)
plt.xlabel("Rating")
plt.ylabel("Gender")
plt.show()

# %% [markdown]
# ### 30) Rating Vs Quantity

# %%
plt.style.use("default")
plt.figure(figsize=(5,5))
sns.barplot(x="Rating", y="Quantity", data=data[170:180])
plt.title("Rating vs Quantity",fontsize=15)
plt.xlabel("Rating")
plt.ylabel("Quantity")
plt.show()

# %%
#lets find the categorialfeatures
list_1=list(data.columns)

# %%
list_cate=[]
for i in list_1:
    if data[i].dtype=='object':
        list_cate.append(i)

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
for i in list_cate:
    data[i]=le.fit_transform(data[i])

# %%
data
# Out:
#      Invoice ID  Branch  City  Customer type  Gender  Product line  \
# 0           814       0     2              0       0             3
# 1           142       2     1              1       0             0
# 2           653       0     2              1       1             4
# 3            18       0     2              0       1             3
# 4           339       0     2              1       1             5
# ..          ...     ...   ...            ...     ...           ...
# 995         153       2     1              1       1             3
# 996         250       1     0              1       0             4
# 997         767       0     2              0       1             2
# 998         308       0     2              1       1             4
# 999         935       0     2              0       0             1
#
#      Unit price  Quantity   Tax 5%      Total  Date  Time  Payment    cogs  \
# 0         74.69         7  26.1415   548.9715    26   146        2  522.83
# ...

# %%
y=data['Gender']
x=data.drop('Gender',axis=1)

# %% [markdown]
# # TRAINING AND TESTING DATA

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=0,test_size=0.2)

# %%
print(len(x_train))
print(len(x_test))
print(len(y_train))
print(len(y_test))
# Out:
# 800
# 200
# 800
# 200

# %% [markdown]
# # Classification

# %% [markdown]
# ### 31) KNeighborsClassifier

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier(n_neighbors=7)

knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=7)

# %%
y_pred=knn.predict(x_test)
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
print("Classification Report is:\n",classification_report(y_test,y_pred))
print("Confusion Matrix:\n",confusion_matrix(y_test,y_pred))
print("Training Score:\n",knn.score(x_train,y_train)*100)
# Out:
# Classification Report is:
#                precision    recall  f1-score   support
#
#            0       0.47      0.49      0.48       100
#            1       0.47      0.45      0.46       100
#
#     accuracy                           0.47       200
#    macro avg       0.47      0.47      0.47       200
# weighted avg       0.47      0.47      0.47       200
#
# Confusion Matrix:
#  [[49 51]
#  [55 45]]
# Training Score:
#  64.75

# %% [markdown]
# ### 32) SVC

# %%
from sklearn.svm import SVC

svc = SVC()
svc.fit(x_train, y_train)
# Out:
# SVC()

# %%
y_pred=svc.predict(x_test)
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
print("Classification Report is:\n",classification_report(y_test,y_pred))
print("Confusion Matrix:\n",confusion_matrix(y_test,y_pred))
print("Training Score:\n",svc.score(x_train,y_train)*100)
# Out:
# Classification Report is:
#                precision    recall  f1-score   support
#
#            0       0.45      0.49      0.47       100
#            1       0.44      0.40      0.42       100
#
#     accuracy                           0.45       200
#    macro avg       0.44      0.45      0.44       200
# weighted avg       0.44      0.45      0.44       200
#
# Confusion Matrix:
#  [[49 51]
#  [60 40]]
# Training Score:
#  55.50000000000001

# %% [markdown]
# ## 33) Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
gnb.fit(x_train,y_train)
# Out:
# GaussianNB()

# %%
y_pred=gnb.predict(x_test)
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
print("Classification Report is:\n",classification_report(y_test,y_pred))
print("Confusion Matrix:\n",confusion_matrix(y_test,y_pred))
print("Training Score:\n",gnb.score(x_train,y_train)*100)
# Out:
# Classification Report is:
#                precision    recall  f1-score   support
#
#            0       0.51      0.35      0.41       100
#            1       0.50      0.66      0.57       100
#
#     accuracy                           0.51       200
#    macro avg       0.51      0.51      0.49       200
# weighted avg       0.51      0.51      0.49       200
#
# Confusion Matrix:
#  [[35 65]
#  [34 66]]
# Training Score:
#  55.125

# %% [markdown]
# ### 34) DECISION TREE CLASSIFIER

# %%
from sklearn.tree import DecisionTreeClassifier
dtree = DecisionTreeClassifier(max_depth=6, random_state=123,criterion='entropy')

dtree.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=6, random_state=123)

# %%
y_pred=dtree.predict(x_test)
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
print("Classification Report is:\n",classification_report(y_test,y_pred))
print("Confusion Matrix:\n",confusion_matrix(y_test,y_pred))
print("Training Score:\n",dtree.score(x_train,y_train)*100)
# Out:
# Classification Report is:
#                precision    recall  f1-score   support
#
#            0       0.52      0.79      0.63       100
#            1       0.56      0.27      0.36       100
#
#     accuracy                           0.53       200
#    macro avg       0.54      0.53      0.50       200
# weighted avg       0.54      0.53      0.50       200
#
# Confusion Matrix:
#  [[79 21]
#  [73 27]]
# Training Score:
#  63.87500000000001

# %% [markdown]
# ### 35) Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
rfc=RandomForestClassifier()
rfc.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred=rfc.predict(x_test)
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
print("Classification Report is:\n",classification_report(y_test,y_pred))
print("Confusion Matrix:\n",confusion_matrix(y_test,y_pred))
print("Training Score:\n",rfc.score(x_train,y_train)*100)
# Out:
# Classification Report is:
#                precision    recall  f1-score   support
#
#            0       0.48      0.52      0.50       100
#            1       0.48      0.44      0.46       100
#
#     accuracy                           0.48       200
#    macro avg       0.48      0.48      0.48       200
# weighted avg       0.48      0.48      0.48       200
#
# Confusion Matrix:
#  [[52 48]
#  [56 44]]
# Training Score:
#  100.0

# %% [markdown]
# ### 36) AdaBoostClassifier

# %%
from sklearn.ensemble import AdaBoostClassifier
adb = AdaBoostClassifier(base_estimator = None)
adb.fit(x_train,y_train)
# Out:
# AdaBoostClassifier()

# %%
y_pred=adb.predict(x_test)
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
print("Classification Report is:\n",classification_report(y_test,y_pred))
print("Confusion Matrix:\n",confusion_matrix(y_test,y_pred))
print("Training Score:\n",adb.score(x_train,y_train)*100)
# Out:
# Classification Report is:
#                precision    recall  f1-score   support
#
#            0       0.54      0.54      0.54       100
#            1       0.54      0.54      0.54       100
#
#     accuracy                           0.54       200
#    macro avg       0.54      0.54      0.54       200
# weighted avg       0.54      0.54      0.54       200
#
# Confusion Matrix:
#  [[54 46]
#  [46 54]]
# Training Score:
#  67.0

# %% [markdown]
# ### 37) Gradient Boosting Classifier

# %%
from sklearn.ensemble import GradientBoostingClassifier
gbc=GradientBoostingClassifier()
gbc.fit(x_train,y_train)
# Out:
# GradientBoostingClassifier()

# %%
y_pred=gbc.predict(x_test)
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
print("Classification Report is:\n",classification_report(y_test,y_pred))
print("Confusion Matrix:\n",confusion_matrix(y_test,y_pred))
print("Training Score:\n",gbc.score(x_train,y_train)*100)
# Out:
# Classification Report is:
#                precision    recall  f1-score   support
#
#            0       0.49      0.51      0.50       100
#            1       0.49      0.47      0.48       100
#
#     accuracy                           0.49       200
#    macro avg       0.49      0.49      0.49       200
# weighted avg       0.49      0.49      0.49       200
#
# Confusion Matrix:
#  [[51 49]
#  [53 47]]
# Training Score:
#  88.0

# %%
data = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
data
# Out:
#      Actual  Predicted
# 993       1          0
# 859       0          0
# 298       1          1
# 553       1          0
# 672       0          0
# ..      ...        ...
# 679       1          0
# 722       1          1
# 215       1          1
# 653       1          1
# 150       0          0
#
# [200 rows x 2 columns]

# %% [markdown]
# ### 38) XGBClassifier

# %%
from xgboost import XGBClassifier

xgb =XGBClassifier(objective ='reg:linear', colsample_bytree = 0.3, learning_rate = 0.1,
                max_depth = 5, alpha = 10, n_estimators = 10)

xgb.fit(x_train, y_train)
# Out:
# [16:56:24] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# XGBClassifier(alpha=10, base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=0.3, gamma=0, gpu_id=-1,
#               importance_type='gain', interaction_constraints='',
#               learning_rate=0.1, max_delta_step=0, max_depth=5,
#               min_child_weight=1, missing=nan, monotone_constraints='()',
#               n_estimators=10, n_jobs=4, num_parallel_tree=1,
#               objective='reg:linear', random_state=0, reg_alpha=10,
#               reg_lambda=1, scale_pos_weight=1, subsample=1,
#               tree_method='exact', validate_parameters=1, verbosity=None)

# %%
y_pred=xgb.predict(x_test)
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
print("Classification Report is:\n",classification_report(y_test,y_pred))
print("Confusion Matrix:\n",confusion_matrix(y_test,y_pred))
print("Training Score:\n",xgb.score(x_train,y_train)*100)
# Out:
# Classification Report is:
#                precision    recall  f1-score   support
#
#            0       0.48      0.49      0.48       100
#            1       0.47      0.46      0.47       100
#
#     accuracy                           0.48       200
#    macro avg       0.47      0.47      0.47       200
# weighted avg       0.47      0.47      0.47       200
#
# Confusion Matrix:
#  [[49 51]
#  [54 46]]
# Training Score:
#  63.87500000000001

# %% [markdown]
# ### 39) ExtraTreesClassifier

# %%
from sklearn.ensemble import ExtraTreesClassifier
etc = ExtraTreesClassifier(n_estimators=100, random_state=0)
etc.fit(x_train,y_train)
# Out:
# ExtraTreesClassifier(random_state=0)

# %%
y_pred=etc.predict(x_test)
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
print("Classification Report is:\n",classification_report(y_test,y_pred))
print("Confusion Matrix:\n",confusion_matrix(y_test,y_pred))
print("Training Score:\n",etc.score(x_train,y_train)*100)
# Out:
# Classification Report is:
#                precision    recall  f1-score   support
#
#            0       0.50      0.50      0.50       100
#            1       0.50      0.50      0.50       100
#
#     accuracy                           0.50       200
#    macro avg       0.50      0.50      0.50       200
# weighted avg       0.50      0.50      0.50       200
#
# Confusion Matrix:
#  [[50 50]
#  [50 50]]
# Training Score:
#  100.0

# %% [markdown]
# ### 40) Bagging Classifier

# %%
from sklearn.ensemble import BaggingClassifier
from sklearn import tree
model = BaggingClassifier(tree.DecisionTreeClassifier(random_state=1))
model.fit(x_train, y_train)
model.score(x_test,y_test)
# Out:
# 0.47

# %%
data = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
data
# Out:
#      Actual  Predicted
# 993       1          1
# 859       0          1
# 298       1          1
# 553       1          0
# 672       0          1
# ..      ...        ...
# 679       1          1
# 722       1          1
# 215       1          0
# 653       1          0
# 150       0          0
#
# [200 rows x 2 columns]

# %% [markdown]
# ### Root Mean Square:

# %%
mean_rating = df['Rating'].mean()
mse = ((df['Rating'] - mean_rating) ** 2).mean()
rms = np.sqrt(mse)

print(f"Root Mean Square (RMS): {rms}")
# Out:
# Root Mean Square (RMS): 1.7177207893019169

# %% [markdown]
# ### Mean Absolute Error:

# %%
mean_rating = df['Rating'].mean()
mae = (df['Rating'] - mean_rating).abs().mean()

print(f"Mean Absolute Error (MAE): {mae}")
# Out:
# Mean Absolute Error (MAE): 1.4775546

# %% [markdown]
# ### Mean Squared Error:

# %%
actual_ratings = df['Rating']
mean_rating = actual_ratings.mean()

# Create a new column with the mean rating for comparison
df['Mean_Rating'] = mean_rating

# Calculate Mean Squared Error
mse = mean_squared_error(actual_ratings, df['Mean_Rating'])

print(f"Mean Squared Error (MSE) for Rating column: {mse}")
# Out:
# Mean Squared Error (MSE) for Rating column: 2.95056471

# %% [markdown]
# ### CONCLUSION :
#
# ACCURACIES OF DIFFERENT MODELS ARE:
#
# KNeighbors Classifier= 64.75 %
#
# SVC= 55.50 %
#
# Naiye Bayes= 55.10 %
#
# Decision Tree Classifier= 64 %
#
# Random Forest Classifier= 100 %
#
# Ada Boost Classifier= 67 %
#
# Gradient Boosting Classifier= 89 %
#
# XGB Classifier= 64 %
#
# Extra Trees Classifier= 100 %
#
# Bagging Classifier = 51 %
#
# We got a good accuracy of about 100 % using Random Forest Classifier.
